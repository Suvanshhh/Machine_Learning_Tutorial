# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\KIIT\MACHINE LEARNING\Insurance_Logi_Reg.csv')

# %%
df
# Out:
#     Age Brought_insurance
# 0    21                no
# 1    45               yes
# 2    32               yes
# 3    41               yes
# 4    20                no
# 5    35               yes
# 6    20                no
# 7    23                no
# 8    42               yes
# 9    34               yes
# 10   24                no
# 11   22                no
# 12   23                no
# 13   25                no

# %%
df['Brought_insurance'].replace({'no':'0','yes':'1'},inplace=True)

# %%
df
# Out:
#     Age Brought_insurance
# 0    21                 0
# 1    45                 1
# 2    32                 1
# 3    41                 1
# 4    20                 0
# 5    35                 1
# 6    20                 0
# 7    23                 0
# 8    42                 1
# 9    34                 1
# 10   24                 0
# 11   22                 0
# 12   23                 0
# 13   25                 0

# %%
plt.scatter(x='Age',y='Brought_insurance',data=df)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df[['Age']],df['Brought_insurance'],test_size=0.2)

# %%
len(x_train)
# Out:
# 11

# %%
x_test
# Out:
#    Age
# 5   35
# 1   45
# 6   20

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.predict(x_test)
# Out:
# array(['1', '1', '0'], dtype=object)

# %%
lr.predict([[60]])
# Out:
# C:\Users\KIIT\New folder\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['1'], dtype=object)

# %%
lr.predict([[23]])
# Out:
# C:\Users\KIIT\New folder\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['0'], dtype=object)
